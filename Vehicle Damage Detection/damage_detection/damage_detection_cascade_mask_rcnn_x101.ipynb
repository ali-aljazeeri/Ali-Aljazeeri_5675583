# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
import random
pylab.rcParams['figure.figsize'] = (8.0, 10.0)
# %matplotlib inline

# For visualization
import os
import seaborn as sns
from matplotlib import colors
from PIL import Image
from tqdm import tqdm

# %% [markdown]
# ### explor the dataset
#
# Description of dataset:
# Car Damage Detection ([CarDD](https://cardd-ustc.github.io)), the first public large-scale dataset designed for vision-based car damage detection and segmentation. CarDD contains 4,000 high-resolution car damage images (2816 train | 810 val | 374 test)  with over 9,000 well-annotated instances of six damage categories.

# %%
# for example the the test train files

annFile = './drive/MyDrive/damage_detection/CarDD_release/CarDD_COCO/annotations/instances_train2017.json'
img_dir = './drive/MyDrive/damage_detection/CarDD_release/CarDD_COCO/train2017'

# %%
coco=COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=5.59s)
# creating index...
# index created!

# %%
# Get all category tags and corresponding category IDs
categories = coco.loadCats(coco.getCatIds())
category_id_to_name = {cat['id']: cat['name'] for cat in categories}

# Print all category IDs and corresponding category names
for category_id, category_name in category_id_to_name.items():
    print(f"Category ID: {category_id}, Category Name: {category_name}")

print("")
print("")
print("----------------")
print("")
# Create a dictionary between category_id and category name
category_map = dict()

for ele in list(coco.cats.values()):
    category_map.update({ele['id']:ele['name']})
    print(category_map)
# Out:
# Category ID: 1, Category Name: dent
# Category ID: 2, Category Name: scratch
# Category ID: 3, Category Name: crack
# Category ID: 4, Category Name: glass shatter
# Category ID: 5, Category Name: lamp broken
# Category ID: 6, Category Name: tire flat
#
#
# ----------------
#
# {1: 'dent'}
# {1: 'dent', 2: 'scratch'}
# {1: 'dent', 2: 'scratch', 3: 'crack'}
# {1: 'dent', 2: 'scratch', 3: 'crack', 4: 'glass shatter'}
# {1: 'dent', 2: 'scratch', 3: 'crack', 4: 'glass shatter', 5: 'lamp broken'}
# {1: 'dent', 2: 'scratch', 3: 'crack', 4: 'glass shatter', 5: 'lamp broken', 6: 'tire flat'}

# %%
# get all images containing 'dent' category, select one at random
catIds = coco.getCatIds(catNms=['dent'])
imgIds = coco.getImgIds(catIds=catIds )
random_img_id = random.choice(imgIds)

# Load the image
imgId = coco.getImgIds(imgIds = [random_img_id])
img = coco.loadImgs(imgId)[0]
print("Image details \n",img)

#get damage annotations
annIds = coco.getAnnIds(imgIds=imgId,iscrowd=None)
anns = coco.loadAnns(annIds)


#Create a list of damage types in the image
damages = []
for region in anns:
    damages.append(category_map[region['category_id']])

print("Damages are:", damages)

#Plot Damages
I = io.imread(img_dir + '/' + img['file_name'])
plt.imshow(I)
plt.axis('off')
coco.showAnns(anns, draw_bbox=True )
# Out:
# Image details
#  {'id': 1550, 'width': 1000, 'height': 667, 'file_name': '001550.jpg', 'license': 0}
# Damages are: ['dent']

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
# Out:
# 2.6.0+cu124
# 12.4

# %% [markdown]
# ## MMDetection

# %%
# !pip install mmengine mmcv==2.1.0
# !rm -rf mmdetection
# !git clone https://github.com/open-mmlab/mmdetection.git
# %cd mmdetection
# !pip install -e .
# Out:
# Collecting mmengine
#   Downloading mmengine-0.10.7-py3-none-any.whl.metadata (20 kB)
# Collecting mmcv==2.1.0
#   Downloading mmcv-2.1.0.tar.gz (471 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.4/471.4 kB 9.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting addict (from mmcv==2.1.0)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (25.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (11.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (6.0.2)
# Collecting yapf (from mmcv==2.1.0)
#   Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmengine) (3.10.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from mmengine) (13.9.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from mmengine) (3.1.0)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.11/dist-packages (from mmengine) (4.12.0.88)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine) (2.19.2)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->mmcv==2.1.0) (4.3.8)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine) (1.17.0)
# Downloading mmengine-0.10.7-py3-none-any.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.7/452.7 kB 36.8 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 24.2 MB/s eta 0:00:00
# Building wheels for collected packages: mmcv
#   Building wheel for mmcv (setup.py) ... done
#   Created wheel for mmcv: filename=mmcv-2.1.0-cp311-cp311-linux_x86_64.whl size=38291449 sha256=0f64ec8f5751135784a3c0b295d5928765559fa388f8b313ef80581c6e25b3ee
#   Stored in directory: /root/.cache/pip/wheels/57/22/96/9bcbfeaa838c1b705a4b2ac082539767fbcc79fa07ec01abcd
# Successfully built mmcv
# Installing collected packages: addict, yapf, mmengine, mmcv
# Successfully installed addict-2.4.0 mmcv-2.1.0 mmengine-0.10.7 yapf-0.43.0
# Cloning into 'mmdetection'...
# remote: Enumerating objects: 38023, done.
# remote: Total 38023 (delta 0), reused 0 (delta 0), pack-reused 38023 (from 1)
# Receiving objects: 100% (38023/38023), 63.18 MiB | 35.88 MiB/s, done.
# Resolving deltas: 100% (26221/26221), done.
# /content/mmdetection
# Obtaining file:///content/mmdetection
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmdet==3.3.0) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmdet==3.3.0) (2.0.2)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.11/dist-packages (from mmdet==3.3.0) (2.0.10)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mmdet==3.3.0) (1.16.1)
# Requirement already satisfied: shapely in /usr/local/lib/python3.11/dist-packages (from mmdet==3.3.0) (2.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from mmdet==3.3.0) (1.17.0)
# Collecting terminaltables (from mmdet==3.3.0)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from mmdet==3.3.0) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmdet==3.3.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmdet==3.3.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmdet==3.3.0) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmdet==3.3.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmdet==3.3.0) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmdet==3.3.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmdet==3.3.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmdet==3.3.0) (2.9.0.post0)
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Installing collected packages: terminaltables, mmdet
#   Running setup.py develop for mmdet
# Successfully installed mmdet-3.3.0 terminaltables-3.1.10

# %%
# Check Pytorch installation
import torch, torchvision
print("torch version:",torch.__version__, "cuda:",torch.cuda.is_available())

# Check MMDetection installation
import mmdet
print("mmdetection:",mmdet.__version__)

# Check mmcv installation
import mmcv
print("mmcv:",mmcv.__version__)

# Check mmengine installation
import mmengine
print("mmengine:",mmengine.__version__)
# Out:
# torch version: 2.6.0+cu124 cuda: True
# mmdetection: 3.3.0
# mmcv: 2.1.0
# mmengine: 0.10.7

# %%
# %matplotlib inline
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import cv2
import random
import pylab
pylab.rcParams['figure.figsize'] = (8.0, 10.0)

import os
import seaborn as sns
from matplotlib import colors
from rich.pretty import pprint
import PIL
from PIL import Image
import json
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import warnings
from tqdm import tqdm
from torch.utils.data import Dataset
from pycocotools.coco import COCO
from mmengine import Config
from mmengine.runner import set_random_seed
import mmcv
from mmdet.registry import VISUALIZERS
from mmdet.apis import init_detector, inference_detector
from mmengine.structures import InstanceData

# %%
# %cd ..
# Out:
# /content

# %%
content = '''
# Copyright (c) OpenMMLab. All rights reserved.
import copy
import os.path as osp
from typing import List, Union

from mmengine.fileio import get_local_path

from mmdet.registry import DATASETS
from .api_wrappers import COCO
from .base_det_dataset import BaseDetDataset


@DATASETS.register_module()
class CocoDataset(BaseDetDataset):
    """Dataset for COCO."""

    METAINFO = {
        'classes':
        ('dent', 'scratch', 'crack', 'glass shatter', 'lamp broken', 'tire flat',),
        # palette is a list of color tuples, which is used for visualization.
        'palette':
        [(220, 20, 60), (119, 11, 32), (0, 0, 142), (0, 0, 230), (106, 0, 228),
         (0, 60, 100)]
    }
    COCOAPI = COCO
    # ann_id is unique in coco dataset.
    ANN_ID_UNIQUE = True

    def load_data_list(self) -> List[dict]:
        """Load annotations from an annotation file named as ``self.ann_file``

        Returns:
            List[dict]: A list of annotation.
        """  # noqa: E501
        with get_local_path(
                self.ann_file, backend_args=self.backend_args) as local_path:
            self.coco = self.COCOAPI(local_path)
        # The order of returned `cat_ids` will not
        # change with the order of the `classes`
        self.cat_ids = self.coco.get_cat_ids(
            cat_names=self.metainfo['classes'])
        self.cat2label = {cat_id: i for i, cat_id in enumerate(self.cat_ids)}
        self.cat_img_map = copy.deepcopy(self.coco.cat_img_map)

        img_ids = self.coco.get_img_ids()
        data_list = []
        total_ann_ids = []
        for img_id in img_ids:
            raw_img_info = self.coco.load_imgs([img_id])[0]
            raw_img_info['img_id'] = img_id

            ann_ids = self.coco.get_ann_ids(img_ids=[img_id])
            raw_ann_info = self.coco.load_anns(ann_ids)
            total_ann_ids.extend(ann_ids)

            parsed_data_info = self.parse_data_info({
                'raw_ann_info':
                raw_ann_info,
                'raw_img_info':
                raw_img_info
            })
            data_list.append(parsed_data_info)
        if self.ANN_ID_UNIQUE:
            assert len(set(total_ann_ids)) == len(
                total_ann_ids
            ), f"Annotation ids in '{self.ann_file}' are not unique!"

        del self.coco

        return data_list

    def parse_data_info(self, raw_data_info: dict) -> Union[dict, List[dict]]:
        """Parse raw annotation to target format.

        Args:
            raw_data_info (dict): Raw data information load from ``ann_file``

        Returns:
            Union[dict, List[dict]]: Parsed annotation.
        """
        img_info = raw_data_info['raw_img_info']
        ann_info = raw_data_info['raw_ann_info']

        data_info = {}

        # TODO: need to change data_prefix['img'] to data_prefix['img_path']
        img_path = osp.join(self.data_prefix['img'], img_info['file_name'])
        if self.data_prefix.get('seg', None):
            seg_map_path = osp.join(
                self.data_prefix['seg'],
                img_info['file_name'].rsplit('.', 1)[0] + self.seg_map_suffix)
        else:
            seg_map_path = None
        data_info['img_path'] = img_path
        data_info['img_id'] = img_info['img_id']
        data_info['seg_map_path'] = seg_map_path
        data_info['height'] = img_info['height']
        data_info['width'] = img_info['width']

        if self.return_classes:
            data_info['text'] = self.metainfo['classes']
            data_info['caption_prompt'] = self.caption_prompt
            data_info['custom_entities'] = True

        instances = []
        for i, ann in enumerate(ann_info):
            instance = {}

            if ann.get('ignore', False):
                continue
            x1, y1, w, h = ann['bbox']
            inter_w = max(0, min(x1 + w, img_info['width']) - max(x1, 0))
            inter_h = max(0, min(y1 + h, img_info['height']) - max(y1, 0))
            if inter_w * inter_h == 0:
                continue
            if ann['area'] <= 0 or w < 1 or h < 1:
                continue
            if ann['category_id'] not in self.cat_ids:
                continue
            bbox = [x1, y1, x1 + w, y1 + h]

            if ann.get('iscrowd', False):
                instance['ignore_flag'] = 1
            else:
                instance['ignore_flag'] = 0
            instance['bbox'] = bbox
            instance['bbox_label'] = self.cat2label[ann['category_id']]

            if ann.get('segmentation', None):
                instance['mask'] = ann['segmentation']

            instances.append(instance)
        data_info['instances'] = instances
        return data_info

    def filter_data(self) -> List[dict]:
        """Filter annotations according to filter_cfg.

        Returns:
            List[dict]: Filtered results.
        """
        if self.test_mode:
            return self.data_list

        if self.filter_cfg is None:
            return self.data_list

        filter_empty_gt = self.filter_cfg.get('filter_empty_gt', False)
        min_size = self.filter_cfg.get('min_size', 0)

        # obtain images that contain annotation
        ids_with_ann = set(data_info['img_id'] for data_info in self.data_list)
        # obtain images that contain annotations of the required categories
        ids_in_cat = set()
        for i, class_id in enumerate(self.cat_ids):
            ids_in_cat |= set(self.cat_img_map[class_id])
        # merge the image id sets of the two conditions and use the merged set
        # to filter out images if self.filter_empty_gt=True
        ids_in_cat &= ids_with_ann

        valid_data_infos = []
        for i, data_info in enumerate(self.data_list):
            img_id = data_info['img_id']
            width = data_info['width']
            height = data_info['height']
            if filter_empty_gt and img_id not in ids_in_cat:
                continue
            if min(width, height) >= min_size:
                valid_data_infos.append(data_info)

        return valid_data_infos
'''
with open('./mmdetection/mmdet/datasets/coco.py', 'w') as f:
    f.write(content.strip())

# %% [markdown]
# ### Customizing the model configuration

# %%
# Below code is loading a model configuration file from MMDetection using the Config class.
cfg = Config.fromfile('mmdetection/configs/dcn/cascade-mask-rcnn_x101-32x4d-dconv-c3-c5_fpn_1x_coco.py')

# %% [markdown]
# Below script is customizing and saving a full training configuration for an

# %%
cfg.load_from = 'https://download.openmmlab.com/mmdetection/v2.0/dcn/cascade_mask_rcnn_x101_32x4d_fpn_dconv_c3-c5_1x_coco/cascade_mask_rcnn_x101_32x4d_fpn_dconv_c3-c5_1x_coco-e75f90c8.pth'
cfg.data_root = './drive/MyDrive/damage_detection/CarDD_release/CarDD_COCO'

classes = ('dent', 'scratch', 'crack', 'glass shatter', 'lamp broken', 'tire flat',)
n_classes = len(classes)

# Set up working dir to save files and logs.
cfg.work_dir = './drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output'

cfg.metainfo = {
    'classes': classes,
    'palette': [(220, 20, 60), (119, 11, 32), (0, 0, 142), (0, 0, 230), (106, 0, 228),
         (0, 60, 100)]
}

# Modify some of the model's properties
cfg.model.backbone.stage_with_dcn = (True, True, True, True)
cfg.model.roi_head.bbox_head[0].num_classes = n_classes
cfg.model.roi_head.bbox_head[1].num_classes = n_classes
cfg.model.roi_head.bbox_head[2].num_classes = n_classes
cfg.model.roi_head.mask_head.num_classes = n_classes
for head in cfg.model.roi_head.bbox_head:
    head.loss_cls = dict(type='FocalLoss', use_sigmoid=True, gamma=2.0, alpha=0.5, loss_weight=1.0)

cfg.train_dataloader.dataset.ann_file = 'annotations/instances_train2017.json'
cfg.train_dataloader.dataset.data_root = cfg.data_root
cfg.train_dataloader.dataset.data_prefix.img = 'train2017/'

cfg.val_dataloader.dataset.ann_file = 'annotations/instances_val2017.json'
cfg.val_dataloader.dataset.data_root = cfg.data_root
cfg.val_dataloader.dataset.data_prefix.img = 'val2017/'

cfg.test_dataloader.dataset.ann_file = 'annotations/instances_test2017.json'
cfg.test_dataloader.dataset.data_root = cfg.data_root
cfg.test_dataloader.dataset.data_prefix.img = 'test2017/'

cfg.val_evaluator = {'type': 'CocoMetric',
 'ann_file': '/content/drive/MyDrive/damage_detection/CarDD_release/CarDD_COCO/annotations/instances_val2017.json',
 'metric': ['bbox','segm'],
 'classwise': True,
 'format_only': False,
 'backend_args': None}

cfg.test_evaluator = {'type': 'CocoMetric',
 'ann_file': '/content/drive/MyDrive/damage_detection/CarDD_release/CarDD_COCO/annotations/instances_test2017.json',
 'metric': ['bbox','segm'],
 'classwise': True,
 'format_only': False,
 'backend_args': None}

cfg.train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
    dict(type='Resize', img_scale=[(1333, 640), (1333, 1200)], multiscale_mode='range', keep_ratio=False, backend='pillow'),
    dict(type='RandomFlip', flip_ratio=0.5),
    dict(type='PackDetInputs')
]

# Schedule the training
cfg.train_cfg.max_epochs = 24
cfg.optim_wrapper.optimizer.lr = 0.005
cfg.param_scheduler[1] = dict(type= 'MultiStepLR', begin= 0, end= 24, by_epoch= True,
                              milestones= [16, 22], gamma= 0.1)

# We can set the evaluation interval
cfg.train_cfg.val_interval = 1

# We can set the checkpoint saving interval
cfg.default_hooks.checkpoint.interval = 1
cfg.default_hooks.logger.interval = 50

# Set seed thus the results are more reproducible
set_random_seed(0, deterministic=False)

# We can also use tensorboard to log the training process
cfg.visualizer.vis_backends.append({"type":'TensorboardVisBackend'})

#------------------------------------------------------

config= './drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_cfg.py'
with open(config, 'w') as f:
    f.write(cfg.pretty_text)

# %% [markdown]
# # Train
# - To train using 1 gpu run:!python mmdetection/tools/train.py dcn_plus_cfg.py
# - To perform distributed training using 2 gpus run the following:

# %%
# !bash mmdetection/tools/dist_train.sh './drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_cfg.py' 1
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/distributed/launch.py:208: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use-env is set by default in torchrun.
# If your script expects `--local-rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   main()
# /usr/local/lib/python3.11/dist-packages/mmengine/utils/dl_utils/setup_env.py:46: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mmengine/utils/dl_utils/setup_env.py:56: UserWarning: Setting MKL_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# 2025-07-19 11:18:14.861177: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752923894.882815   17977 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752923894.889281   17977 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 07/19 11:18:17 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1235522336
#     GPU 0: NVIDIA A100-SXM4-40GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.5, V12.5.82
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.6.0+cu124
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2024.2-Product Build 20240605 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.5.3 (Git Hash 66f0cb9eb66affd2da3bf5f8d897376f04aae6af)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.5
#   - Built with CUDA Runtime 12.4
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 90.3  (built against CUDA 12.6)
#     - Built with CuDNN 90.1
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, COMMIT_SHA=2236df1770800ffea5697b11b0bb0d910b2e59e1, CUDA_VERSION=12.4, CUDNN_VERSION=9.1.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DLIBKINETO_NOXPUPTI=ON -DUSE_FBGEMM -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wsuggest-override -Wno-psabi -Wno-error=old-style-cast -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, TORCH_VERSION=2.6.0, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=1, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.21.0+cu124
#     OpenCV: 4.12.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 1235522336
#     Distributed launcher: pytorch
#     Distributed training: True
#     GPU number: 1
# ------------------------------------------------------------
#
# 07/19 11:18:18 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = './drive/MyDrive/damage_detection/CarDD_release/CarDD_COCO'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(interval=1, type='CheckpointHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'pytorch'
# load_from = 'https://download.openmmlab.com/mmdetection/v2.0/dcn/cascade_mask_rcnn_x101_32x4d_fpn_dconv_c3-c5_1x_coco/cascade_mask_rcnn_x101_32x4d_fpn_dconv_c3-c5_1x_coco-e75f90c8.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# metainfo = dict(
#     classes=(
#         'dent',
#         'scratch',
#         'crack',
#         'glass shatter',
#         'lamp broken',
#         'tire flat',
#     ),
#     palette=[
#         (
#             220,
#             20,
#             60,
#         ),
#         (
#             119,
#             11,
#             32,
#         ),
#         (
#             0,
#             0,
#             142,
#         ),
#         (
#             0,
#             0,
#             230,
#         ),
#         (
#             106,
#             0,
#             228,
#         ),
#         (
#             0,
#             60,
#             100,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         base_width=4,
#         dcn=dict(deform_groups=1, fallback_on_stride=False, type='DCN'),
#         depth=101,
#         frozen_stages=1,
#         groups=32,
#         init_cfg=dict(
#             checkpoint='open-mmlab://resnext101_32x4d', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         stage_with_dcn=(
#             True,
#             True,
#             True,
#             True,
#         ),
#         style='pytorch',
#         type='ResNeXt'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_mask=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     alpha=0.5,
#                     gamma=2.0,
#                     loss_weight=1.0,
#                     type='FocalLoss',
#                     use_sigmoid=True),
#                 num_classes=6,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     alpha=0.5,
#                     gamma=2.0,
#                     loss_weight=1.0,
#                     type='FocalLoss',
#                     use_sigmoid=True),
#                 num_classes=6,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     alpha=0.5,
#                     gamma=2.0,
#                     loss_weight=1.0,
#                     type='FocalLoss',
#                     use_sigmoid=True),
#                 num_classes=6,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         mask_head=dict(
#             conv_out_channels=256,
#             in_channels=256,
#             loss_mask=dict(
#                 loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#             num_classes=6,
#             num_convs=4,
#             type='FCNMaskHead'),
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='CascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.05),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=True,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='CascadeRCNN')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.005, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=24,
#         gamma=0.1,
#         milestones=[
#             16,
#             22,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='annotations/instances_test2017.json',
#         backend_args=None,
#         data_prefix=dict(img='test2017/'),
#         data_root='./drive/MyDrive/damage_detection/CarDD_release/CarDD_COCO',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file=
#     '/content/drive/MyDrive/damage_detection/CarDD_release/CarDD_COCO/annotations/instances_test2017.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=24, type='EpochBasedTrainLoop', val_interval=1)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file='annotations/instances_train2017.json',
#         backend_args=None,
#         data_prefix=dict(img='train2017/'),
#         data_root='./drive/MyDrive/damage_detection/CarDD_release/CarDD_COCO',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         backend='pillow',
#         img_scale=[
#             (
#                 1333,
#                 640,
#             ),
#             (
#                 1333,
#                 1200,
#             ),
#         ],
#         keep_ratio=False,
#         multiscale_mode='range',
#         type='Resize'),
#     dict(flip_ratio=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='annotations/instances_val2017.json',
#         backend_args=None,
#         data_prefix=dict(img='val2017/'),
#         data_root='./drive/MyDrive/damage_detection/CarDD_release/CarDD_COCO',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file=
#     '/content/drive/MyDrive/damage_detection/CarDD_release/CarDD_COCO/annotations/instances_val2017.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#     ])
# work_dir = './drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output'
#
# 07/19 11:18:22 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.20s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=1.08s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# 07/19 11:18:25 - mmengine - INFO - load model from: open-mmlab://resnext101_32x4d
# 07/19 11:18:25 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://resnext101_32x4d
# Downloading: "https://download.openmmlab.com/pretrain/third_party/resnext101_32x4d-a5af3160.pth" to /root/.cache/torch/hub/checkpoints/resnext101_32x4d-a5af3160.pth
# 100% 161M/161M [00:07<00:00, 22.5MB/s]
# 07/19 11:18:33 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: layer1.0.conv2.conv_offset.weight, layer1.0.conv2.conv_offset.bias, layer1.1.conv2.conv_offset.weight, layer1.1.conv2.conv_offset.bias, layer1.2.conv2.conv_offset.weight, layer1.2.conv2.conv_offset.bias, layer2.0.conv2.conv_offset.weight, layer2.0.conv2.conv_offset.bias, layer2.1.conv2.conv_offset.weight, layer2.1.conv2.conv_offset.bias, layer2.2.conv2.conv_offset.weight, layer2.2.conv2.conv_offset.bias, layer2.3.conv2.conv_offset.weight, layer2.3.conv2.conv_offset.bias, layer3.0.conv2.conv_offset.weight, layer3.0.conv2.conv_offset.bias, layer3.1.conv2.conv_offset.weight, layer3.1.conv2.conv_offset.bias, layer3.2.conv2.conv_offset.weight, layer3.2.conv2.conv_offset.bias, layer3.3.conv2.conv_offset.weight, layer3.3.conv2.conv_offset.bias, layer3.4.conv2.conv_offset.weight, layer3.4.conv2.conv_offset.bias, layer3.5.conv2.conv_offset.weight, layer3.5.conv2.conv_offset.bias, layer3.6.conv2.conv_offset.weight, layer3.6.conv2.conv_offset.bias, layer3.7.conv2.conv_offset.weight, layer3.7.conv2.conv_offset.bias, layer3.8.conv2.conv_offset.weight, layer3.8.conv2.conv_offset.bias, layer3.9.conv2.conv_offset.weight, layer3.9.conv2.conv_offset.bias, layer3.10.conv2.conv_offset.weight, layer3.10.conv2.conv_offset.bias, layer3.11.conv2.conv_offset.weight, layer3.11.conv2.conv_offset.bias, layer3.12.conv2.conv_offset.weight, layer3.12.conv2.conv_offset.bias, layer3.13.conv2.conv_offset.weight, layer3.13.conv2.conv_offset.bias, layer3.14.conv2.conv_offset.weight, layer3.14.conv2.conv_offset.bias, layer3.15.conv2.conv_offset.weight, layer3.15.conv2.conv_offset.bias, layer3.16.conv2.conv_offset.weight, layer3.16.conv2.conv_offset.bias, layer3.17.conv2.conv_offset.weight, layer3.17.conv2.conv_offset.bias, layer3.18.conv2.conv_offset.weight, layer3.18.conv2.conv_offset.bias, layer3.19.conv2.conv_offset.weight, layer3.19.conv2.conv_offset.bias, layer3.20.conv2.conv_offset.weight, layer3.20.conv2.conv_offset.bias, layer3.21.conv2.conv_offset.weight, layer3.21.conv2.conv_offset.bias, layer3.22.conv2.conv_offset.weight, layer3.22.conv2.conv_offset.bias, layer4.0.conv2.conv_offset.weight, layer4.0.conv2.conv_offset.bias, layer4.1.conv2.conv_offset.weight, layer4.1.conv2.conv_offset.bias, layer4.2.conv2.conv_offset.weight, layer4.2.conv2.conv_offset.bias
#
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmdetection/v2.0/dcn/cascade_mask_rcnn_x101_32x4d_fpn_dconv_c3-c5_1x_coco/cascade_mask_rcnn_x101_32x4d_fpn_dconv_c3-c5_1x_coco-e75f90c8.pth
# Downloading: "https://download.openmmlab.com/mmdetection/v2.0/dcn/cascade_mask_rcnn_x101_32x4d_fpn_dconv_c3-c5_1x_coco/cascade_mask_rcnn_x101_32x4d_fpn_dconv_c3-c5_1x_coco-e75f90c8.pth" to /root/.cache/torch/hub/checkpoints/cascade_mask_rcnn_x101_32x4d_fpn_dconv_c3-c5_1x_coco-e75f90c8.pth
# 100% 376M/376M [00:12<00:00, 32.6MB/s]
# The model and loaded state dict do not match exactly
#
# size mismatch for roi_head.bbox_head.0.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([7, 1024]).
# size mismatch for roi_head.bbox_head.0.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([7]).
# size mismatch for roi_head.bbox_head.1.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([7, 1024]).
# size mismatch for roi_head.bbox_head.1.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([7]).
# size mismatch for roi_head.bbox_head.2.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([7, 1024]).
# size mismatch for roi_head.bbox_head.2.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([7]).
# size mismatch for roi_head.mask_head.0.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([6, 256, 1, 1]).
# size mismatch for roi_head.mask_head.0.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([6]).
# size mismatch for roi_head.mask_head.1.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([6, 256, 1, 1]).
# size mismatch for roi_head.mask_head.1.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([6]).
# size mismatch for roi_head.mask_head.2.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([6, 256, 1, 1]).
# size mismatch for roi_head.mask_head.2.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([6]).
# missing keys in source state_dict: backbone.layer1.0.conv2.conv_offset.weight, backbone.layer1.0.conv2.conv_offset.bias, backbone.layer1.1.conv2.conv_offset.weight, backbone.layer1.1.conv2.conv_offset.bias, backbone.layer1.2.conv2.conv_offset.weight, backbone.layer1.2.conv2.conv_offset.bias
#
# 07/19 11:18:46 - mmengine - INFO - Load checkpoint from https://download.openmmlab.com/mmdetection/v2.0/dcn/cascade_mask_rcnn_x101_32x4d_fpn_dconv_c3-c5_1x_coco/cascade_mask_rcnn_x101_32x4d_fpn_dconv_c3-c5_1x_coco-e75f90c8.pth
# 07/19 11:18:46 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 07/19 11:18:46 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 07/19 11:18:46 - mmengine - INFO - Checkpoints will be saved to /content/drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output.
# 07/19 11:19:34 - mmengine - INFO - Epoch(train)  [1][  50/1408]  lr: 4.9549e-04  eta: 8:59:41  time: 0.9597  data_time: 0.4848  memory: 7355  loss: 1.9885  loss_rpn_cls: 0.1250  loss_rpn_bbox: 0.0248  s0.loss_cls: 0.2485  s0.acc: 96.3867  s0.loss_bbox: 0.0648  s0.loss_mask: 0.6990  s1.loss_cls: 0.1613  s1.acc: 96.6797  s1.loss_bbox: 0.0411  s1.loss_mask: 0.3409  s2.loss_cls: 0.0876  s2.acc: 96.5820  s2.loss_bbox: 0.0160  s2.loss_mask: 0.1796
# 07/19 11:20:17 - mmengine - INFO - Epoch(train)  [1][ 100/1408]  lr: 9.9599e-04  eta: 8:33:00  time: 0.8675  data_time: 0.4480  memory: 7269  loss: 1.2685  loss_rpn_cls: 0.0397  loss_rpn_bbox: 0.0231  s0.loss_cls: 0.0480  s0.acc: 97.3633  s0.loss_bbox: 0.0725  s0.loss_mask: 0.5645  s1.loss_cls: 0.0229  s1.acc: 97.4609  s1.loss_bbox: 0.0485  s1.loss_mask: 0.2761  s2.loss_cls: 0.0111  s2.acc: 97.9492  s2.loss_bbox: 0.0179  s2.loss_mask: 0.1441
# 07/19 11:21:01 - mmengine - INFO - Epoch(train)  [1][ 150/1408]  lr: 1.4965e-03  eta: 8:25:23  time: 0.8769  data_time: 0.4553  memory: 7305  loss: 0.9593  loss_rpn_cls: 0.0363  loss_rpn_bbox: 0.0174  s0.loss_cls: 0.0445  s0.acc: 97.3633  s0.loss_bbox: 0.0625  s0.loss_mask: 0.4065  s1.loss_cls: 0.0232  s1.acc: 97.4609  s1.loss_bbox: 0.0481  s1.loss_mask: 0.1876  s2.loss_cls: 0.0122  s2.acc: 98.8281  s2.loss_bbox: 0.0229  s2.loss_mask: 0.0980
# 07/19 11:21:45 - mmengine - INFO - Epoch(train)  [1][ 200/1408]  lr: 1.9970e-03  eta: 8:20:14  time: 0.8700  data_time: 0.4496  memory: 7444  loss: 0.9314  loss_rpn_cls: 0.0433  loss_rpn_bbox: 0.0160  s0.loss_cls: 0.0416  s0.acc: 98.2422  s0.loss_bbox: 0.0592  s0.loss_mask: 0.3932  s1.loss_cls: 0.0215  s1.acc: 98.1445  s1.loss_bbox: 0.0503  s1.loss_mask: 0.1820  s2.loss_cls: 0.0110  s2.acc: 98.3398  s2.loss_bbox: 0.0234  s2.loss_mask: 0.0898
# 07/19 11:22:29 - mmengine - INFO - Epoch(train)  [1][ 250/1408]  lr: 2.4975e-03  eta: 8:17:16  time: 0.8736  data_time: 0.4484  memory: 7296  loss: 0.8996  loss_rpn_cls: 0.0305  loss_rpn_bbox: 0.0135  s0.loss_cls: 0.0435  s0.acc: 97.0703  s0.loss_bbox: 0.0655  s0.loss_mask: 0.3708  s1.loss_cls: 0.0221  s1.acc: 97.3633  s1.loss_bbox: 0.0555  s1.loss_mask: 0.1789  s2.loss_cls: 0.0109  s2.acc: 97.8516  s2.loss_bbox: 0.0250  s2.loss_mask: 0.0834
# 07/19 11:23:13 - mmengine - INFO - Epoch(train)  [1][ 300/1408]  lr: 2.9980e-03  eta: 8:16:19  time: 0.8874  data_time: 0.4653  memory: 7685  loss: 0.8291  loss_rpn_cls: 0.0260  loss_rpn_bbox: 0.0177  s0.loss_cls: 0.0389  s0.acc: 98.8281  s0.loss_bbox: 0.0518  s0.loss_mask: 0.3496  s1.loss_cls: 0.0203  s1.acc: 99.2188  s1.loss_bbox: 0.0500  s1.loss_mask: 0.1624  s2.loss_cls: 0.0105  s2.acc: 99.4141  s2.loss_bbox: 0.0258  s2.loss_mask: 0.0762
# 07/19 11:23:56 - mmengine - INFO - Epoch(train)  [1][ 350/1408]  lr: 3.4985e-03  eta: 8:12:46  time: 0.8538  data_time: 0.4323  memory: 7358  loss: 0.9085  loss_rpn_cls: 0.0342  loss_rpn_bbox: 0.0177  s0.loss_cls: 0.0410  s0.acc: 95.4102  s0.loss_bbox: 0.0676  s0.loss_mask: 0.3730  s1.loss_cls: 0.0207  s1.acc: 96.0938  s1.loss_bbox: 0.0610  s1.loss_mask: 0.1739  s2.loss_cls: 0.0099  s2.acc: 92.6758  s2.loss_bbox: 0.0280  s2.loss_mask: 0.0816
# 07/19 11:24:38 - mmengine - INFO - Epoch(train)  [1][ 400/1408]  lr: 3.9990e-03  eta: 8:10:01  time: 0.8551  data_time: 0.4306  memory: 7478  loss: 0.8713  loss_rpn_cls: 0.0288  loss_rpn_bbox: 0.0213  s0.loss_cls: 0.0454  s0.acc: 92.7734  s0.loss_bbox: 0.0747  s0.loss_mask: 0.3359  s1.loss_cls: 0.0235  s1.acc: 92.3828  s1.loss_bbox: 0.0657  s1.loss_mask: 0.1598  s2.loss_cls: 0.0112  s2.acc: 92.1875  s2.loss_bbox: 0.0315  s2.loss_mask: 0.0733
# 07/19 11:25:20 - mmengine - INFO - Epoch(train)  [1][ 450/1408]  lr: 4.4995e-03  eta: 8:05:56  time: 0.8263  data_time: 0.4018  memory: 7304  loss: 0.9112  loss_rpn_cls: 0.0306  loss_rpn_bbox: 0.0154  s0.loss_cls: 0.0489  s0.acc: 90.2344  s0.loss_bbox: 0.0797  s0.loss_mask: 0.3506  s1.loss_cls: 0.0241  s1.acc: 89.9414  s1.loss_bbox: 0.0672  s1.loss_mask: 0.1726  s2.loss_cls: 0.0116  s2.acc: 92.1875  s2.loss_bbox: 0.0300  s2.loss_mask: 0.0806
# 07/19 11:26:04 - mmengine - INFO - Epoch(train)  [1][ 500/1408]  lr: 5.0000e-03  eta: 8:06:14  time: 0.8930  data_time: 0.4709  memory: 7668  loss: 0.9297  loss_rpn_cls: 0.0432  loss_rpn_bbox: 0.0171  s0.loss_cls: 0.0465  s0.acc: 92.8711  s0.loss_bbox: 0.0759  s0.loss_mask: 0.3590  s1.loss_cls: 0.0235  s1.acc: 95.1172  s1.loss_bbox: 0.0695  s1.loss_mask: 0.1741  s2.loss_cls: 0.0112  s2.acc: 95.6055  s2.loss_bbox: 0.0320  s2.loss_mask: 0.0777
# 07/19 11:26:48 - mmengine - INFO - Epoch(train)  [1][ 550/1408]  lr: 5.0000e-03  eta: 8:05:39  time: 0.8790  data_time: 0.4539  memory: 7721  loss: 0.8774  loss_rpn_cls: 0.0211  loss_rpn_bbox: 0.0160  s0.loss_cls: 0.0461  s0.acc: 94.8242  s0.loss_bbox: 0.0813  s0.loss_mask: 0.3325  s1.loss_cls: 0.0231  s1.acc: 95.8008  s1.loss_bbox: 0.0743  s1.loss_mask: 0.1625  s2.loss_cls: 0.0108  s2.acc: 93.4570  s2.loss_bbox: 0.0342  s2.loss_mask: 0.0756
# 07/19 11:27:32 - mmengine - INFO - Epoch(train)  [1][ 600/1408]  lr: 5.0000e-03  eta: 8:04:47  time: 0.8736  data_time: 0.4473  memory: 7740  loss: 0.8505  loss_rpn_cls: 0.0258  loss_rpn_bbox: 0.0182  s0.loss_cls: 0.0392  s0.acc: 94.3359  s0.loss_bbox: 0.0718  s0.loss_mask: 0.3343  s1.loss_cls: 0.0193  s1.acc: 94.0430  s1.loss_bbox: 0.0704  s1.loss_mask: 0.1583  s2.loss_cls: 0.0090  s2.acc: 96.1914  s2.loss_bbox: 0.0330  s2.loss_mask: 0.0711
# 07/19 11:28:16 - mmengine - INFO - Epoch(train)  [1][ 650/1408]  lr: 5.0000e-03  eta: 8:04:33  time: 0.8883  data_time: 0.4638  memory: 7491  loss: 0.7771  loss_rpn_cls: 0.0169  loss_rpn_bbox: 0.0137  s0.loss_cls: 0.0323  s0.acc: 97.6562  s0.loss_bbox: 0.0583  s0.loss_mask: 0.3195  s1.loss_cls: 0.0171  s1.acc: 98.4375  s1.loss_bbox: 0.0586  s1.loss_mask: 0.1537  s2.loss_cls: 0.0084  s2.acc: 98.6328  s2.loss_bbox: 0.0284  s2.loss_mask: 0.0703
# 07/19 11:29:00 - mmengine - INFO - Epoch(train)  [1][ 700/1408]  lr: 5.0000e-03  eta: 8:03:22  time: 0.8655  data_time: 0.4422  memory: 7712  loss: 0.8082  loss_rpn_cls: 0.0237  loss_rpn_bbox: 0.0195  s0.loss_cls: 0.0369  s0.acc: 98.7305  s0.loss_bbox: 0.0674  s0.loss_mask: 0.3215  s1.loss_cls: 0.0188  s1.acc: 98.4375  s1.loss_bbox: 0.0609  s1.loss_mask: 0.1535  s2.loss_cls: 0.0090  s2.acc: 96.2891  s2.loss_bbox: 0.0273  s2.loss_mask: 0.0698
# 07/19 11:29:45 - mmengine - INFO - Epoch(train)  [1][ 750/1408]  lr: 5.0000e-03  eta: 8:04:05  time: 0.9159  data_time: 0.4957  memory: 7390  loss: 0.7514  loss_rpn_cls: 0.0209  loss_rpn_bbox: 0.0176  s0.loss_cls: 0.0294  s0.acc: 98.2422  s0.loss_bbox: 0.0505  s0.loss_mask: 0.3189  s1.loss_cls: 0.0150  s1.acc: 97.2656  s1.loss_bbox: 0.0472  s1.loss_mask: 0.1502  s2.loss_cls: 0.0073  s2.acc: 99.7070  s2.loss_bbox: 0.0241  s2.loss_mask: 0.0703
# 07/19 11:30:28 - mmengine - INFO - Epoch(train)  [1][ 800/1408]  lr: 5.0000e-03  eta: 8:02:14  time: 0.8468  data_time: 0.4247  memory: 7484  loss: 0.7698  loss_rpn_cls: 0.0219  loss_rpn_bbox: 0.0118  s0.loss_cls: 0.0319  s0.acc: 96.5820  s0.loss_bbox: 0.0584  s0.loss_mask: 0.3152  s1.loss_cls: 0.0158  s1.acc: 97.2656  s1.loss_bbox: 0.0571  s1.loss_mask: 0.1512  s2.loss_cls: 0.0077  s2.acc: 97.1680  s2.loss_bbox: 0.0308  s2.loss_mask: 0.0681
# 07/19 11:31:13 - mmengine - INFO - Epoch(train)  [1][ 850/1408]  lr: 5.0000e-03  eta: 8:02:19  time: 0.9022  data_time: 0.4817  memory: 7366  loss: 0.8807  loss_rpn_cls: 0.0342  loss_rpn_bbox: 0.0181  s0.loss_cls: 0.0364  s0.acc: 94.1406  s0.loss_bbox: 0.0678  s0.loss_mask: 0.3636  s1.loss_cls: 0.0171  s1.acc: 95.4102  s1.loss_bbox: 0.0582  s1.loss_mask: 0.1709  s2.loss_cls: 0.0076  s2.acc: 98.2422  s2.loss_bbox: 0.0276  s2.loss_mask: 0.0792
# 07/19 11:31:56 - mmengine - INFO - Epoch(train)  [1][ 900/1408]  lr: 5.0000e-03  eta: 8:00:59  time: 0.8585  data_time: 0.4348  memory: 7542  loss: 0.8129  loss_rpn_cls: 0.0323  loss_rpn_bbox: 0.0226  s0.loss_cls: 0.0366  s0.acc: 96.3867  s0.loss_bbox: 0.0629  s0.loss_mask: 0.3120  s1.loss_cls: 0.0185  s1.acc: 96.8750  s1.loss_bbox: 0.0590  s1.loss_mask: 0.1573  s2.loss_cls: 0.0089  s2.acc: 95.9961  s2.loss_bbox: 0.0299  s2.loss_mask: 0.0726
# 07/19 11:32:38 - mmengine - INFO - Epoch(train)  [1][ 950/1408]  lr: 5.0000e-03  eta: 7:59:29  time: 0.8505  data_time: 0.4205  memory: 7419  loss: 0.8459  loss_rpn_cls: 0.0279  loss_rpn_bbox: 0.0166  s0.loss_cls: 0.0395  s0.acc: 98.9258  s0.loss_bbox: 0.0788  s0.loss_mask: 0.3194  s1.loss_cls: 0.0202  s1.acc: 98.4375  s1.loss_bbox: 0.0726  s1.loss_mask: 0.1530  s2.loss_cls: 0.0094  s2.acc: 99.6094  s2.loss_bbox: 0.0357  s2.loss_mask: 0.0729
# 07/19 11:33:21 - mmengine - INFO - Exp name: cascade-mask-rcnn_x101_cfg_20250719_111813
# 07/19 11:33:21 - mmengine - INFO - Epoch(train)  [1][1000/1408]  lr: 5.0000e-03  eta: 7:58:15  time: 0.8580  data_time: 0.4269  memory: 7861  loss: 0.8547  loss_rpn_cls: 0.0313  loss_rpn_bbox: 0.0201  s0.loss_cls: 0.0406  s0.acc: 93.0664  s0.loss_bbox: 0.0790  s0.loss_mask: 0.3264  s1.loss_cls: 0.0201  s1.acc: 92.4805  s1.loss_bbox: 0.0689  s1.loss_mask: 0.1536  s2.loss_cls: 0.0096  s2.acc: 93.0664  s2.loss_bbox: 0.0330  s2.loss_mask: 0.0722
# 07/19 11:34:05 - mmengine - INFO - Epoch(train)  [1][1050/1408]  lr: 5.0000e-03  eta: 7:57:37  time: 0.8786  data_time: 0.4480  memory: 7458  loss: 0.8281  loss_rpn_cls: 0.0197  loss_rpn_bbox: 0.0148  s0.loss_cls: 0.0370  s0.acc: 97.1680  s0.loss_bbox: 0.0667  s0.loss_mask: 0.3178  s1.loss_cls: 0.0189  s1.acc: 97.5586  s1.loss_bbox: 0.0659  s1.loss_mask: 0.1646  s2.loss_cls: 0.0089  s2.acc: 97.3633  s2.loss_bbox: 0.0326  s2.loss_mask: 0.0813
# 07/19 11:34:49 - mmengine - INFO - Epoch(train)  [1][1100/1408]  lr: 5.0000e-03  eta: 7:57:10  time: 0.8866  data_time: 0.4569  memory: 7324  loss: 0.7467  loss_rpn_cls: 0.0181  loss_rpn_bbox: 0.0154  s0.loss_cls: 0.0320  s0.acc: 96.6797  s0.loss_bbox: 0.0636  s0.loss_mask: 0.3060  s1.loss_cls: 0.0162  s1.acc: 95.9961  s1.loss_bbox: 0.0564  s1.loss_mask: 0.1408  s2.loss_cls: 0.0074  s2.acc: 97.3633  s2.loss_bbox: 0.0277  s2.loss_mask: 0.0631
# 07/19 11:35:34 - mmengine - INFO - Epoch(train)  [1][1150/1408]  lr: 5.0000e-03  eta: 7:56:50  time: 0.8924  data_time: 0.4525  memory: 7387  loss: 0.7991  loss_rpn_cls: 0.0233  loss_rpn_bbox: 0.0192  s0.loss_cls: 0.0357  s0.acc: 98.9258  s0.loss_bbox: 0.0619  s0.loss_mask: 0.3082  s1.loss_cls: 0.0184  s1.acc: 98.5352  s1.loss_bbox: 0.0635  s1.loss_mask: 0.1527  s2.loss_cls: 0.0086  s2.acc: 96.3867  s2.loss_bbox: 0.0339  s2.loss_mask: 0.0737
# 07/19 11:36:18 - mmengine - INFO - Epoch(train)  [1][1200/1408]  lr: 5.0000e-03  eta: 7:55:58  time: 0.8706  data_time: 0.4376  memory: 7427  loss: 0.8069  loss_rpn_cls: 0.0217  loss_rpn_bbox: 0.0176  s0.loss_cls: 0.0368  s0.acc: 96.5820  s0.loss_bbox: 0.0667  s0.loss_mask: 0.3012  s1.loss_cls: 0.0198  s1.acc: 97.1680  s1.loss_bbox: 0.0707  s1.loss_mask: 0.1519  s2.loss_cls: 0.0098  s2.acc: 95.7031  s2.loss_bbox: 0.0388  s2.loss_mask: 0.0719
# 07/19 11:37:00 - mmengine - INFO - Epoch(train)  [1][1250/1408]  lr: 5.0000e-03  eta: 7:54:25  time: 0.8382  data_time: 0.4072  memory: 7759  loss: 0.8125  loss_rpn_cls: 0.0211  loss_rpn_bbox: 0.0160  s0.loss_cls: 0.0387  s0.acc: 99.3164  s0.loss_bbox: 0.0720  s0.loss_mask: 0.3143  s1.loss_cls: 0.0194  s1.acc: 98.8281  s1.loss_bbox: 0.0683  s1.loss_mask: 0.1506  s2.loss_cls: 0.0090  s2.acc: 96.8750  s2.loss_bbox: 0.0330  s2.loss_mask: 0.0700
# 07/19 11:37:43 - mmengine - INFO - Epoch(train)  [1][1300/1408]  lr: 5.0000e-03  eta: 7:53:44  time: 0.8769  data_time: 0.4471  memory: 8028  loss: 0.7464  loss_rpn_cls: 0.0270  loss_rpn_bbox: 0.0123  s0.loss_cls: 0.0333  s0.acc: 92.3828  s0.loss_bbox: 0.0670  s0.loss_mask: 0.2893  s1.loss_cls: 0.0168  s1.acc: 95.8008  s1.loss_bbox: 0.0635  s1.loss_mask: 0.1325  s2.loss_cls: 0.0081  s2.acc: 95.8008  s2.loss_bbox: 0.0325  s2.loss_mask: 0.0641
# 07/19 11:38:29 - mmengine - INFO - Epoch(train)  [1][1350/1408]  lr: 5.0000e-03  eta: 7:53:37  time: 0.9056  data_time: 0.4764  memory: 7540  loss: 0.8092  loss_rpn_cls: 0.0298  loss_rpn_bbox: 0.0146  s0.loss_cls: 0.0318  s0.acc: 98.5352  s0.loss_bbox: 0.0644  s0.loss_mask: 0.3267  s1.loss_cls: 0.0159  s1.acc: 99.7070  s1.loss_bbox: 0.0645  s1.loss_mask: 0.1537  s2.loss_cls: 0.0075  s2.acc: 99.7070  s2.loss_bbox: 0.0313  s2.loss_mask: 0.0690
# 07/19 11:39:17 - mmengine - INFO - Epoch(train)  [1][1400/1408]  lr: 5.0000e-03  eta: 7:54:48  time: 0.9755  data_time: 0.5451  memory: 7351  loss: 0.7725  loss_rpn_cls: 0.0299  loss_rpn_bbox: 0.0135  s0.loss_cls: 0.0324  s0.acc: 95.8008  s0.loss_bbox: 0.0585  s0.loss_mask: 0.3036  s1.loss_cls: 0.0164  s1.acc: 93.9453  s1.loss_bbox: 0.0568  s1.loss_mask: 0.1523  s2.loss_cls: 0.0078  s2.acc: 93.8477  s2.loss_bbox: 0.0294  s2.loss_mask: 0.0719
# 07/19 11:39:28 - mmengine - INFO - Exp name: cascade-mask-rcnn_x101_cfg_20250719_111813
# 07/19 11:39:28 - mmengine - INFO - Saving checkpoint at 1 epochs
# /content/mmdetection/mmdet/models/roi_heads/mask_heads/fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#   mask_preds = bboxes.new_tensor(mask_preds)
# 07/19 11:39:52 - mmengine - INFO - Epoch(val)  [1][ 50/810]    eta: 0:05:21  time: 0.4225  data_time: 0.1774  memory: 7467
# 07/19 11:40:12 - mmengine - INFO - Epoch(val)  [1][100/810]    eta: 0:04:54  time: 0.4070  data_time: 0.1864  memory: 2169
# 07/19 11:40:31 - mmengine - INFO - Epoch(val)  [1][150/810]    eta: 0:04:25  time: 0.3775  data_time: 0.1392  memory: 2170
# 07/19 11:40:51 - mmengine - INFO - Epoch(val)  [1][200/810]    eta: 0:04:03  time: 0.3909  data_time: 0.1579  memory: 2457
# 07/19 11:41:09 - mmengine - INFO - Epoch(val)  [1][250/810]    eta: 0:03:40  time: 0.3678  data_time: 0.1453  memory: 2170
# 07/19 11:41:28 - mmengine - INFO - Epoch(val)  [1][300/810]    eta: 0:03:19  time: 0.3824  data_time: 0.1474  memory: 2328
# 07/19 11:41:48 - mmengine - INFO - Epoch(val)  [1][350/810]    eta: 0:02:59  time: 0.3867  data_time: 0.1337  memory: 2278
# 07/19 11:42:08 - mmengine - INFO - Epoch(val)  [1][400/810]    eta: 0:02:41  time: 0.4108  data_time: 0.1649  memory: 2169
# 07/19 11:42:30 - mmengine - INFO - Epoch(val)  [1][450/810]    eta: 0:02:23  time: 0.4314  data_time: 0.1847  memory: 2324
# 07/19 11:42:50 - mmengine - INFO - Epoch(val)  [1][500/810]    eta: 0:02:03  time: 0.4108  data_time: 0.1618  memory: 2457
# 07/19 11:43:10 - mmengine - INFO - Epoch(val)  [1][550/810]    eta: 0:01:43  time: 0.3922  data_time: 0.1361  memory: 2283
# 07/19 11:43:30 - mmengine - INFO - Epoch(val)  [1][600/810]    eta: 0:01:23  time: 0.4069  data_time: 0.1598  memory: 2457
# 07/19 11:43:51 - mmengine - INFO - Epoch(val)  [1][650/810]    eta: 0:01:04  time: 0.4213  data_time: 0.2355  memory: 2169
# 07/19 11:44:13 - mmengine - INFO - Epoch(val)  [1][700/810]    eta: 0:00:44  time: 0.4251  data_time: 0.2012  memory: 2297
# 07/19 11:44:33 - mmengine - INFO - Epoch(val)  [1][750/810]    eta: 0:00:24  time: 0.4076  data_time: 0.1632  memory: 2225
# 07/19 11:44:56 - mmengine - INFO - Epoch(val)  [1][800/810]    eta: 0:00:04  time: 0.4668  data_time: 0.2715  memory: 2169
# 07/19 11:45:05 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.51s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.33s).
# Accumulating evaluation results...
# DONE (t=1.41s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.382
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.491
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.403
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.067
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.041
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.390
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.652
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.652
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.652
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.352
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.298
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.661
# 07/19 11:45:09 - mmengine - INFO -
# +---------------+-------+--------+--------+-------+-------+-------+
# | category      | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +---------------+-------+--------+--------+-------+-------+-------+
# | dent          | 0.136 | 0.295  | 0.113  | 0.005 | 0.049 | 0.153 |
# | scratch       | 0.178 | 0.347  | 0.159  | 0.018 | 0.098 | 0.215 |
# | crack         | 0.064 | 0.118  | 0.067  | 0.178 | 0.055 | 0.017 |
# | glass shatter | 0.871 | 0.948  | 0.945  | nan   | nan   | 0.871 |
# | lamp broken   | 0.304 | 0.418  | 0.327  | nan   | 0.002 | 0.311 |
# | tire flat     | 0.738 | 0.819  | 0.807  | nan   | 0.0   | 0.774 |
# +---------------+-------+--------+--------+-------+-------+-------+
# 07/19 11:45:09 - mmengine - INFO - bbox_mAP_copypaste: 0.382 0.491 0.403 0.067 0.041 0.390
# 07/19 11:45:09 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=1.18s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=3.23s).
# Accumulating evaluation results...
# DONE (t=1.39s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.368
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.474
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.382
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.008
# ...
# 07/19 16:18:08 - mmengine - INFO - Epoch(train) [24][ 500/1408]  lr: 5.0000e-05  eta: 0:07:03  time: 0.4504  data_time: 0.0144  memory: 8279  loss: 0.1997  loss_rpn_cls: 0.0008  loss_rpn_bbox: 0.0024  s0.loss_cls: 0.0060  s0.acc: 99.4141  s0.loss_bbox: 0.0069  s0.loss_mask: 0.0829  s1.loss_cls: 0.0028  s1.acc: 99.5117  s1.loss_bbox: 0.0103  s1.loss_mask: 0.0497  s2.loss_cls: 0.0014  s2.acc: 99.4141  s2.loss_bbox: 0.0104  s2.loss_mask: 0.0260
# 07/19 16:18:31 - mmengine - INFO - Epoch(train) [24][ 550/1408]  lr: 5.0000e-05  eta: 0:06:40  time: 0.4524  data_time: 0.0132  memory: 8226  loss: 0.1872  loss_rpn_cls: 0.0012  loss_rpn_bbox: 0.0020  s0.loss_cls: 0.0050  s0.acc: 98.9258  s0.loss_bbox: 0.0065  s0.loss_mask: 0.0780  s1.loss_cls: 0.0022  s1.acc: 99.4990  s1.loss_bbox: 0.0093  s1.loss_mask: 0.0471  s2.loss_cls: 0.0010  s2.acc: 98.7718  s2.loss_bbox: 0.0101  s2.loss_mask: 0.0249
# 07/19 16:18:54 - mmengine - INFO - Epoch(train) [24][ 600/1408]  lr: 5.0000e-05  eta: 0:06:16  time: 0.4591  data_time: 0.0152  memory: 8255  loss: 0.2322  loss_rpn_cls: 0.0012  loss_rpn_bbox: 0.0023  s0.loss_cls: 0.0074  s0.acc: 99.9023  s0.loss_bbox: 0.0100  s0.loss_mask: 0.0922  s1.loss_cls: 0.0032  s1.acc: 99.9023  s1.loss_bbox: 0.0149  s1.loss_mask: 0.0553  s2.loss_cls: 0.0017  s2.acc: 99.8047  s2.loss_bbox: 0.0151  s2.loss_mask: 0.0288
# 07/19 16:19:01 - mmengine - INFO - Exp name: cascade-mask-rcnn_x101_cfg_20250719_111813
# 07/19 16:19:16 - mmengine - INFO - Epoch(train) [24][ 650/1408]  lr: 5.0000e-05  eta: 0:05:53  time: 0.4510  data_time: 0.0137  memory: 8147  loss: 0.2116  loss_rpn_cls: 0.0012  loss_rpn_bbox: 0.0020  s0.loss_cls: 0.0053  s0.acc: 98.3398  s0.loss_bbox: 0.0073  s0.loss_mask: 0.0895  s1.loss_cls: 0.0022  s1.acc: 98.6000  s1.loss_bbox: 0.0098  s1.loss_mask: 0.0541  s2.loss_cls: 0.0012  s2.acc: 98.0691  s2.loss_bbox: 0.0108  s2.loss_mask: 0.0283
# 07/19 16:19:39 - mmengine - INFO - Epoch(train) [24][ 700/1408]  lr: 5.0000e-05  eta: 0:05:30  time: 0.4526  data_time: 0.0143  memory: 7994  loss: 0.2139  loss_rpn_cls: 0.0008  loss_rpn_bbox: 0.0025  s0.loss_cls: 0.0056  s0.acc: 99.2188  s0.loss_bbox: 0.0074  s0.loss_mask: 0.0910  s1.loss_cls: 0.0021  s1.acc: 98.9258  s1.loss_bbox: 0.0111  s1.loss_mask: 0.0525  s2.loss_cls: 0.0012  s2.acc: 99.1133  s2.loss_bbox: 0.0121  s2.loss_mask: 0.0276
# 07/19 16:20:01 - mmengine - INFO - Epoch(train) [24][ 750/1408]  lr: 5.0000e-05  eta: 0:05:06  time: 0.4508  data_time: 0.0135  memory: 8775  loss: 0.2064  loss_rpn_cls: 0.0006  loss_rpn_bbox: 0.0020  s0.loss_cls: 0.0056  s0.acc: 98.8281  s0.loss_bbox: 0.0064  s0.loss_mask: 0.0872  s1.loss_cls: 0.0021  s1.acc: 99.8047  s1.loss_bbox: 0.0098  s1.loss_mask: 0.0523  s2.loss_cls: 0.0011  s2.acc: 99.7070  s2.loss_bbox: 0.0117  s2.loss_mask: 0.0276
# 07/19 16:20:24 - mmengine - INFO - Epoch(train) [24][ 800/1408]  lr: 5.0000e-05  eta: 0:04:43  time: 0.4459  data_time: 0.0128  memory: 7821  loss: 0.1956  loss_rpn_cls: 0.0007  loss_rpn_bbox: 0.0022  s0.loss_cls: 0.0053  s0.acc: 99.6094  s0.loss_bbox: 0.0072  s0.loss_mask: 0.0814  s1.loss_cls: 0.0021  s1.acc: 99.2188  s1.loss_bbox: 0.0105  s1.loss_mask: 0.0487  s2.loss_cls: 0.0011  s2.acc: 99.4141  s2.loss_bbox: 0.0104  s2.loss_mask: 0.0258
# 07/19 16:20:46 - mmengine - INFO - Epoch(train) [24][ 850/1408]  lr: 5.0000e-05  eta: 0:04:20  time: 0.4536  data_time: 0.0136  memory: 8376  loss: 0.2090  loss_rpn_cls: 0.0008  loss_rpn_bbox: 0.0021  s0.loss_cls: 0.0061  s0.acc: 98.7305  s0.loss_bbox: 0.0079  s0.loss_mask: 0.0850  s1.loss_cls: 0.0027  s1.acc: 98.5104  s1.loss_bbox: 0.0117  s1.loss_mask: 0.0517  s2.loss_cls: 0.0014  s2.acc: 98.7730  s2.loss_bbox: 0.0123  s2.loss_mask: 0.0273
# 07/19 16:21:09 - mmengine - INFO - Epoch(train) [24][ 900/1408]  lr: 5.0000e-05  eta: 0:03:56  time: 0.4497  data_time: 0.0132  memory: 8245  loss: 0.2074  loss_rpn_cls: 0.0007  loss_rpn_bbox: 0.0020  s0.loss_cls: 0.0052  s0.acc: 99.5117  s0.loss_bbox: 0.0073  s0.loss_mask: 0.0877  s1.loss_cls: 0.0022  s1.acc: 99.9023  s1.loss_bbox: 0.0108  s1.loss_mask: 0.0523  s2.loss_cls: 0.0013  s2.acc: 99.8047  s2.loss_bbox: 0.0104  s2.loss_mask: 0.0274
# 07/19 16:21:31 - mmengine - INFO - Epoch(train) [24][ 950/1408]  lr: 5.0000e-05  eta: 0:03:33  time: 0.4515  data_time: 0.0134  memory: 8222  loss: 0.1920  loss_rpn_cls: 0.0006  loss_rpn_bbox: 0.0021  s0.loss_cls: 0.0057  s0.acc: 98.5352  s0.loss_bbox: 0.0064  s0.loss_mask: 0.0802  s1.loss_cls: 0.0026  s1.acc: 97.8516  s1.loss_bbox: 0.0095  s1.loss_mask: 0.0485  s2.loss_cls: 0.0013  s2.acc: 97.8516  s2.loss_bbox: 0.0097  s2.loss_mask: 0.0254
# 07/19 16:21:54 - mmengine - INFO - Epoch(train) [24][1000/1408]  lr: 5.0000e-05  eta: 0:03:10  time: 0.4528  data_time: 0.0135  memory: 8258  loss: 0.2051  loss_rpn_cls: 0.0010  loss_rpn_bbox: 0.0018  s0.loss_cls: 0.0061  s0.acc: 99.5117  s0.loss_bbox: 0.0072  s0.loss_mask: 0.0848  s1.loss_cls: 0.0026  s1.acc: 99.6094  s1.loss_bbox: 0.0112  s1.loss_mask: 0.0507  s2.loss_cls: 0.0014  s2.acc: 99.7056  s2.loss_bbox: 0.0118  s2.loss_mask: 0.0266
# 07/19 16:22:17 - mmengine - INFO - Epoch(train) [24][1050/1408]  lr: 5.0000e-05  eta: 0:02:46  time: 0.4552  data_time: 0.0137  memory: 8421  loss: 0.2121  loss_rpn_cls: 0.0014  loss_rpn_bbox: 0.0026  s0.loss_cls: 0.0065  s0.acc: 99.2188  s0.loss_bbox: 0.0071  s0.loss_mask: 0.0895  s1.loss_cls: 0.0027  s1.acc: 99.5117  s1.loss_bbox: 0.0105  s1.loss_mask: 0.0522  s2.loss_cls: 0.0013  s2.acc: 99.5117  s2.loss_bbox: 0.0109  s2.loss_mask: 0.0273
# 07/19 16:22:39 - mmengine - INFO - Epoch(train) [24][1100/1408]  lr: 5.0000e-05  eta: 0:02:23  time: 0.4515  data_time: 0.0140  memory: 8151  loss: 0.1956  loss_rpn_cls: 0.0008  loss_rpn_bbox: 0.0018  s0.loss_cls: 0.0052  s0.acc: 99.9023  s0.loss_bbox: 0.0066  s0.loss_mask: 0.0822  s1.loss_cls: 0.0021  s1.acc: 99.8047  s1.loss_bbox: 0.0093  s1.loss_mask: 0.0501  s2.loss_cls: 0.0011  s2.acc: 100.0000  s2.loss_bbox: 0.0099  s2.loss_mask: 0.0266
# 07/19 16:23:02 - mmengine - INFO - Epoch(train) [24][1150/1408]  lr: 5.0000e-05  eta: 0:02:00  time: 0.4542  data_time: 0.0136  memory: 8098  loss: 0.1960  loss_rpn_cls: 0.0005  loss_rpn_bbox: 0.0019  s0.loss_cls: 0.0059  s0.acc: 99.4141  s0.loss_bbox: 0.0063  s0.loss_mask: 0.0833  s1.loss_cls: 0.0028  s1.acc: 99.3164  s1.loss_bbox: 0.0086  s1.loss_mask: 0.0502  s2.loss_cls: 0.0014  s2.acc: 99.5117  s2.loss_bbox: 0.0090  s2.loss_mask: 0.0261
# 07/19 16:23:25 - mmengine - INFO - Epoch(train) [24][1200/1408]  lr: 5.0000e-05  eta: 0:01:36  time: 0.4539  data_time: 0.0155  memory: 8272  loss: 0.2163  loss_rpn_cls: 0.0010  loss_rpn_bbox: 0.0021  s0.loss_cls: 0.0063  s0.acc: 99.2188  s0.loss_bbox: 0.0082  s0.loss_mask: 0.0890  s1.loss_cls: 0.0027  s1.acc: 99.2188  s1.loss_bbox: 0.0123  s1.loss_mask: 0.0528  s2.loss_cls: 0.0013  s2.acc: 99.2188  s2.loss_bbox: 0.0129  s2.loss_mask: 0.0276
# 07/19 16:23:47 - mmengine - INFO - Epoch(train) [24][1250/1408]  lr: 5.0000e-05  eta: 0:01:13  time: 0.4489  data_time: 0.0137  memory: 8391  loss: 0.1913  loss_rpn_cls: 0.0015  loss_rpn_bbox: 0.0021  s0.loss_cls: 0.0049  s0.acc: 99.7070  s0.loss_bbox: 0.0056  s0.loss_mask: 0.0809  s1.loss_cls: 0.0024  s1.acc: 99.4141  s1.loss_bbox: 0.0084  s1.loss_mask: 0.0490  s2.loss_cls: 0.0013  s2.acc: 98.6328  s2.loss_bbox: 0.0094  s2.loss_mask: 0.0259
# 07/19 16:24:10 - mmengine - INFO - Epoch(train) [24][1300/1408]  lr: 5.0000e-05  eta: 0:00:50  time: 0.4507  data_time: 0.0138  memory: 8132  loss: 0.2053  loss_rpn_cls: 0.0009  loss_rpn_bbox: 0.0023  s0.loss_cls: 0.0063  s0.acc: 99.2188  s0.loss_bbox: 0.0071  s0.loss_mask: 0.0856  s1.loss_cls: 0.0027  s1.acc: 99.1063  s1.loss_bbox: 0.0101  s1.loss_mask: 0.0518  s2.loss_cls: 0.0014  s2.acc: 98.8855  s2.loss_bbox: 0.0101  s2.loss_mask: 0.0270
# 07/19 16:24:33 - mmengine - INFO - Epoch(train) [24][1350/1408]  lr: 5.0000e-05  eta: 0:00:27  time: 0.4539  data_time: 0.0138  memory: 8296  loss: 0.1997  loss_rpn_cls: 0.0012  loss_rpn_bbox: 0.0018  s0.loss_cls: 0.0052  s0.acc: 99.6094  s0.loss_bbox: 0.0069  s0.loss_mask: 0.0851  s1.loss_cls: 0.0019  s1.acc: 99.7070  s1.loss_bbox: 0.0094  s1.loss_mask: 0.0509  s2.loss_cls: 0.0009  s2.acc: 99.8047  s2.loss_bbox: 0.0098  s2.loss_mask: 0.0267
# 07/19 16:24:55 - mmengine - INFO - Epoch(train) [24][1400/1408]  lr: 5.0000e-05  eta: 0:00:03  time: 0.4514  data_time: 0.0139  memory: 8413  loss: 0.1960  loss_rpn_cls: 0.0007  loss_rpn_bbox: 0.0019  s0.loss_cls: 0.0059  s0.acc: 99.6094  s0.loss_bbox: 0.0072  s0.loss_mask: 0.0814  s1.loss_cls: 0.0025  s1.acc: 100.0000  s1.loss_bbox: 0.0103  s1.loss_mask: 0.0491  s2.loss_cls: 0.0013  s2.acc: 100.0000  s2.loss_bbox: 0.0102  s2.loss_mask: 0.0257
# 07/19 16:24:59 - mmengine - INFO - Exp name: cascade-mask-rcnn_x101_cfg_20250719_111813
# 07/19 16:24:59 - mmengine - INFO - Saving checkpoint at 24 epochs
# /content/mmdetection/mmdet/models/roi_heads/mask_heads/fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#   mask_preds = bboxes.new_tensor(mask_preds)
# 07/19 16:25:09 - mmengine - INFO - Epoch(val) [24][ 50/810]    eta: 0:01:48  time: 0.1425  data_time: 0.0399  memory: 7636
# 07/19 16:25:14 - mmengine - INFO - Epoch(val) [24][100/810]    eta: 0:01:27  time: 0.1030  data_time: 0.0047  memory: 1628
# 07/19 16:25:19 - mmengine - INFO - Epoch(val) [24][150/810]    eta: 0:01:17  time: 0.1052  data_time: 0.0051  memory: 1640
# 07/19 16:25:24 - mmengine - INFO - Epoch(val) [24][200/810]    eta: 0:01:08  time: 0.1006  data_time: 0.0046  memory: 1620
# 07/19 16:25:29 - mmengine - INFO - Epoch(val) [24][250/810]    eta: 0:01:01  time: 0.0986  data_time: 0.0045  memory: 1620
# 07/19 16:25:34 - mmengine - INFO - Epoch(val) [24][300/810]    eta: 0:00:55  time: 0.0990  data_time: 0.0048  memory: 1620
# 07/19 16:25:39 - mmengine - INFO - Epoch(val) [24][350/810]    eta: 0:00:49  time: 0.1010  data_time: 0.0052  memory: 1640
# 07/19 16:25:45 - mmengine - INFO - Epoch(val) [24][400/810]    eta: 0:00:43  time: 0.1046  data_time: 0.0062  memory: 1605
# 07/19 16:25:50 - mmengine - INFO - Epoch(val) [24][450/810]    eta: 0:00:38  time: 0.0984  data_time: 0.0046  memory: 1620
# 07/19 16:25:55 - mmengine - INFO - Epoch(val) [24][500/810]    eta: 0:00:32  time: 0.1037  data_time: 0.0058  memory: 1620
# 07/19 16:26:00 - mmengine - INFO - Epoch(val) [24][550/810]    eta: 0:00:27  time: 0.1017  data_time: 0.0052  memory: 1620
# 07/19 16:26:05 - mmengine - INFO - Epoch(val) [24][600/810]    eta: 0:00:22  time: 0.1019  data_time: 0.0050  memory: 1640
# 07/19 16:26:10 - mmengine - INFO - Epoch(val) [24][650/810]    eta: 0:00:16  time: 0.0977  data_time: 0.0046  memory: 1640
# 07/19 16:26:15 - mmengine - INFO - Epoch(val) [24][700/810]    eta: 0:00:11  time: 0.1001  data_time: 0.0050  memory: 1620
# 07/19 16:26:20 - mmengine - INFO - Epoch(val) [24][750/810]    eta: 0:00:06  time: 0.1020  data_time: 0.0051  memory: 1620
# 07/19 16:26:25 - mmengine - INFO - Epoch(val) [24][800/810]    eta: 0:00:01  time: 0.0989  data_time: 0.0046  memory: 1640
# 07/19 16:26:26 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.54s).
# Accumulating evaluation results...
# DONE (t=0.16s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.584
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.741
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.602
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.139
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.223
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.572
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.680
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.680
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.680
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.178
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.330
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.700
# 07/19 16:26:27 - mmengine - INFO -
# +---------------+-------+--------+--------+-------+-------+-------+
# | category      | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +---------------+-------+--------+--------+-------+-------+-------+
# | dent          | 0.322 | 0.586  | 0.334  | 0.042 | 0.124 | 0.356 |
# | scratch       | 0.351 | 0.618  | 0.351  | 0.084 | 0.271 | 0.389 |
# | crack         | 0.283 | 0.524  | 0.291  | 0.293 | 0.393 | 0.094 |
# | glass shatter | 0.95  | 0.98   | 0.969  | nan   | nan   | 0.95  |
# | lamp broken   | 0.698 | 0.818  | 0.748  | nan   | 0.09  | 0.71  |
# | tire flat     | 0.897 | 0.919  | 0.919  | nan   | 0.236 | 0.934 |
# +---------------+-------+--------+--------+-------+-------+-------+
# 07/19 16:26:27 - mmengine - INFO - bbox_mAP_copypaste: 0.584 0.741 0.602 0.139 0.223 0.572
# 07/19 16:26:27 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.07s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.64s).
# Accumulating evaluation results...
# DONE (t=0.16s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.547
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.724
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.541
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.068
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.128
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.631
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.631
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.631
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.121
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.270
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.646
# 07/19 16:26:28 - mmengine - INFO -
# +---------------+-------+--------+--------+-------+-------+-------+
# | category      | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +---------------+-------+--------+--------+-------+-------+-------+
# | dent          | 0.3   | 0.588  | 0.287  | 0.012 | 0.097 | 0.334 |
# | scratch       | 0.296 | 0.577  | 0.26   | 0.05  | 0.165 | 0.346 |
# | crack         | 0.155 | 0.453  | 0.063  | 0.142 | 0.183 | 0.138 |
# | glass shatter | 0.941 | 0.98   | 0.969  | nan   | nan   | 0.941 |
# | lamp broken   | 0.696 | 0.826  | 0.751  | nan   | 0.059 | 0.708 |
# | tire flat     | 0.894 | 0.919  | 0.919  | nan   | 0.135 | 0.93  |
# +---------------+-------+--------+--------+-------+-------+-------+
# 07/19 16:26:28 - mmengine - INFO - segm_mAP_copypaste: 0.547 0.724 0.541 0.068 0.128 0.566
# 07/19 16:26:28 - mmengine - INFO - Epoch(val) [24][810/810]    coco/dent_precision: 0.3000  coco/scratch_precision: 0.2960  coco/crack_precision: 0.1550  coco/glass shatter_precision: 0.9410  coco/lamp broken_precision: 0.6960  coco/tire flat_precision: 0.8940  coco/bbox_mAP: 0.5840  coco/bbox_mAP_50: 0.7410  coco/bbox_mAP_75: 0.6020  coco/bbox_mAP_s: 0.1390  coco/bbox_mAP_m: 0.2230  coco/bbox_mAP_l: 0.5720  coco/segm_mAP: 0.5470  coco/segm_mAP_50: 0.7240  coco/segm_mAP_75: 0.5410  coco/segm_mAP_s: 0.0680  coco/segm_mAP_m: 0.1280  coco/segm_mAP_l: 0.5660  data_time: 0.0072  time: 0.1036
# [rank0]:[W719 16:26:29.432757992 ProcessGroupNCCL.cpp:1496] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())

# %% [markdown]
# ### Plots

# %%
# !python mmdetection/tools/analysis_tools/analyze_logs.py \
plot_curve drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/20250719_111813/vis_data/scalars.json \
--keys loss \
--out drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/loss.jpg \
--legend loss \
--title 'total loss'
# Out:
# plot curve of drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/20250719_111813/vis_data/scalars.json, metric is loss
# save curve to: drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/loss.jpg

# %%
cm = mmcv.imread('drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/loss.jpg')
cm = mmcv.imconvert(cm, 'bgr', 'rgb')
plt.imshow(cm)
plt.axis('off')
plt.show()

# %%
# !python mmdetection/tools/analysis_tools/analyze_logs.py\
 plot_curve drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/20250719_111813/vis_data/scalars.json\
  --keys segm_mAP segm_mAP_50 segm_mAP_75\
  --out drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/segm_mAP.jpg\
  --legend mAP mAP_50 mAP_75 --title 'segmentation mAP'
# Out:
# plot curve of drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/20250719_111813/vis_data/scalars.json, metric is segm_mAP
# plot curve of drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/20250719_111813/vis_data/scalars.json, metric is segm_mAP_50
# plot curve of drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/20250719_111813/vis_data/scalars.json, metric is segm_mAP_75
# save curve to: drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/segm_mAP.jpg

# %%
cm = mmcv.imread('drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/segm_mAP.jpg')
cm = mmcv.imconvert(cm, 'bgr', 'rgb')
plt.imshow(cm)
plt.axis('off')
plt.show()

# %% [markdown]
# ### test

# %%
from mmengine.runner import load_checkpoint

# Load full checkpoint
checkpoint = torch.load('drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/epoch_24.pth', weights_only=False)

# Save only model weights
torch.save(checkpoint['state_dict'], 'drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/epoch_24_weights_only.pth')

# %%
# !python mmdetection/tools/test.py \
 drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_cfg.py \
 drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/epoch_24_weights_only.pth \
 --out drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/predictions.pkl
# Out:
# 2025-07-19 16:45:24.547333: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752943524.568075  100316 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752943524.574379  100316 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 07/19 16:45:27 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 849771580
#     GPU 0: NVIDIA A100-SXM4-40GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.5, V12.5.82
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.6.0+cu124
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2024.2-Product Build 20240605 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.5.3 (Git Hash 66f0cb9eb66affd2da3bf5f8d897376f04aae6af)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.5
#   - Built with CUDA Runtime 12.4
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 90.3  (built against CUDA 12.6)
#     - Built with CuDNN 90.1
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, COMMIT_SHA=2236df1770800ffea5697b11b0bb0d910b2e59e1, CUDA_VERSION=12.4, CUDNN_VERSION=9.1.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DLIBKINETO_NOXPUPTI=ON -DUSE_FBGEMM -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wsuggest-override -Wno-psabi -Wno-error=old-style-cast -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, TORCH_VERSION=2.6.0, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=1, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.21.0+cu124
#     OpenCV: 4.12.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 849771580
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 07/19 16:45:28 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = './drive/MyDrive/damage_detection/CarDD_release/CarDD_COCO'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(interval=1, type='CheckpointHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = 'drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/epoch_24_weights_only.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# metainfo = dict(
#     classes=(
#         'dent',
#         'scratch',
#         'crack',
#         'glass shatter',
#         'lamp broken',
#         'tire flat',
#     ),
#     palette=[
#         (
#             220,
#             20,
#             60,
#         ),
#         (
#             119,
#             11,
#             32,
#         ),
#         (
#             0,
#             0,
#             142,
#         ),
#         (
#             0,
#             0,
#             230,
#         ),
#         (
#             106,
#             0,
#             228,
#         ),
#         (
#             0,
#             60,
#             100,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         base_width=4,
#         dcn=dict(deform_groups=1, fallback_on_stride=False, type='DCN'),
#         depth=101,
#         frozen_stages=1,
#         groups=32,
#         init_cfg=dict(
#             checkpoint='open-mmlab://resnext101_32x4d', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         stage_with_dcn=(
#             True,
#             True,
#             True,
#             True,
#         ),
#         style='pytorch',
#         type='ResNeXt'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_mask=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     alpha=0.5,
#                     gamma=2.0,
#                     loss_weight=1.0,
#                     type='FocalLoss',
#                     use_sigmoid=True),
#                 num_classes=6,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     alpha=0.5,
#                     gamma=2.0,
#                     loss_weight=1.0,
#                     type='FocalLoss',
#                     use_sigmoid=True),
#                 num_classes=6,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     alpha=0.5,
#                     gamma=2.0,
#                     loss_weight=1.0,
#                     type='FocalLoss',
#                     use_sigmoid=True),
#                 num_classes=6,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         mask_head=dict(
#             conv_out_channels=256,
#             in_channels=256,
#             loss_mask=dict(
#                 loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#             num_classes=6,
#             num_convs=4,
#             type='FCNMaskHead'),
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='CascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.05),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=True,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='CascadeRCNN')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.005, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=24,
#         gamma=0.1,
#         milestones=[
#             16,
#             22,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='annotations/instances_test2017.json',
#         backend_args=None,
#         data_prefix=dict(img='test2017/'),
#         data_root='./drive/MyDrive/damage_detection/CarDD_release/CarDD_COCO',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file=
#     '/content/drive/MyDrive/damage_detection/CarDD_release/CarDD_COCO/annotations/instances_test2017.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=24, type='EpochBasedTrainLoop', val_interval=1)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file='annotations/instances_train2017.json',
#         backend_args=None,
#         data_prefix=dict(img='train2017/'),
#         data_root='./drive/MyDrive/damage_detection/CarDD_release/CarDD_COCO',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         backend='pillow',
#         img_scale=[
#             (
#                 1333,
#                 640,
#             ),
#             (
#                 1333,
#                 1200,
#             ),
#         ],
#         keep_ratio=False,
#         multiscale_mode='range',
#         type='Resize'),
#     dict(flip_ratio=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='annotations/instances_val2017.json',
#         backend_args=None,
#         data_prefix=dict(img='val2017/'),
#         data_root='./drive/MyDrive/damage_detection/CarDD_release/CarDD_COCO',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file=
#     '/content/drive/MyDrive/damage_detection/CarDD_release/CarDD_COCO/annotations/instances_val2017.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#     ])
# work_dir = './drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output'
#
# 07/19 16:45:30 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 07/19 16:45:30 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.95s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# 07/19 16:45:32 - mmengine - WARNING - The prefix is not set in metric class DumpDetResults.
# Loads checkpoint by local backend from path: drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/epoch_24_weights_only.pth
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer1.0.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer1.1.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer1.2.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer2.0.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer2.1.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer2.2.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer2.3.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.0.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.1.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.2.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.3.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.4.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.5.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.6.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.7.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.8.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.9.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.10.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.11.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.12.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.13.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.14.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.15.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.16.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.17.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.18.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.19.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.20.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.21.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer3.22.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer4.0.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer4.1.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - DeformConv2dPack backbone.layer4.2.conv2 is upgraded to version 2.
# 07/19 16:45:32 - mmengine - INFO - Load checkpoint from drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/epoch_24_weights_only.pth
# /content/mmdetection/mmdet/models/roi_heads/mask_heads/fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#   mask_preds = bboxes.new_tensor(mask_preds)
# 07/19 16:45:54 - mmengine - INFO - Epoch(test) [ 50/374]    eta: 0:02:16  time: 0.4225  data_time: 0.2978  memory: 861
# 07/19 16:46:14 - mmengine - INFO - Epoch(test) [100/374]    eta: 0:01:53  time: 0.4079  data_time: 0.3023  memory: 880
# 07/19 16:46:34 - mmengine - INFO - Epoch(test) [150/374]    eta: 0:01:32  time: 0.4040  data_time: 0.3008  memory: 880
# 07/19 16:46:54 - mmengine - INFO - Epoch(test) [200/374]    eta: 0:01:11  time: 0.4020  data_time: 0.2951  memory: 868
# 07/19 16:47:14 - mmengine - INFO - Epoch(test) [250/374]    eta: 0:00:50  time: 0.3973  data_time: 0.2854  memory: 861
# 07/19 16:47:34 - mmengine - INFO - Epoch(test) [300/374]    eta: 0:00:30  time: 0.4048  data_time: 0.3053  memory: 861
# 07/19 16:47:55 - mmengine - INFO - Epoch(test) [350/374]    eta: 0:00:09  time: 0.4027  data_time: 0.3026  memory: 861
# 07/19 16:48:04 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.26s).
# Accumulating evaluation results...
# DONE (t=0.09s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.624
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.794
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.660
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.299
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.617
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.710
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.710
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.710
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.325
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.464
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.713
# 07/19 16:48:04 - mmengine - INFO -
# +---------------+-------+--------+--------+-------+-------+-------+
# | category      | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +---------------+-------+--------+--------+-------+-------+-------+
# | dent          | 0.405 | 0.687  | 0.438  | 0.252 | 0.27  | 0.426 |
# | scratch       | 0.438 | 0.712  | 0.467  | 0.353 | 0.357 | 0.467 |
# | crack         | 0.337 | 0.588  | 0.366  | 0.292 | 0.424 | 0.206 |
# | glass shatter | 0.932 | 0.974  | 0.962  | nan   | nan   | 0.933 |
# | lamp broken   | 0.712 | 0.848  | 0.775  | nan   | 0.35  | 0.752 |
# | tire flat     | 0.921 | 0.955  | 0.955  | nan   | nan   | 0.921 |
# +---------------+-------+--------+--------+-------+-------+-------+
# 07/19 16:48:04 - mmengine - INFO - bbox_mAP_copypaste: 0.624 0.794 0.660 0.299 0.350 0.617
# 07/19 16:48:04 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.35s).
# Accumulating evaluation results...
# DONE (t=0.08s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.573
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.775
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.574
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.262
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.268
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.588
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.654
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.654
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.654
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.316
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.397
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.650
# 07/19 16:48:05 - mmengine - INFO -
# +---------------+-------+--------+--------+-------+-------+-------+
# | category      | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +---------------+-------+--------+--------+-------+-------+-------+
# | dent          | 0.374 | 0.687  | 0.374  | 0.252 | 0.235 | 0.396 |
# | scratch       | 0.351 | 0.703  | 0.298  | 0.398 | 0.231 | 0.396 |
# | crack         | 0.167 | 0.483  | 0.102  | 0.135 | 0.202 | 0.153 |
# | glass shatter | 0.912 | 0.974  | 0.962  | nan   | nan   | 0.912 |
# | lamp broken   | 0.713 | 0.848  | 0.788  | nan   | 0.404 | 0.748 |
# | tire flat     | 0.923 | 0.955  | 0.92   | nan   | nan   | 0.923 |
# +---------------+-------+--------+--------+-------+-------+-------+
# 07/19 16:48:05 - mmengine - INFO - segm_mAP_copypaste: 0.573 0.775 0.574 0.262 0.268 0.588
# 07/19 16:48:05 - mmengine - INFO - Results has been saved to drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/predictions.pkl.
# 07/19 16:48:05 - mmengine - INFO - Epoch(test) [374/374]    coco/dent_precision: 0.3740  coco/scratch_precision: 0.3510  coco/crack_precision: 0.1670  coco/glass shatter_precision: 0.9120  coco/lamp broken_precision: 0.7130  coco/tire flat_precision: 0.9230  coco/bbox_mAP: 0.6240  coco/bbox_mAP_50: 0.7940  coco/bbox_mAP_75: 0.6600  coco/bbox_mAP_s: 0.2990  coco/bbox_mAP_m: 0.3500  coco/bbox_mAP_l: 0.6170  coco/segm_mAP: 0.5730  coco/segm_mAP_50: 0.7750  coco/segm_mAP_75: 0.5740  coco/segm_mAP_s: 0.2620  coco/segm_mAP_m: 0.2680  coco/segm_mAP_l: 0.5880  data_time: 0.2983  time: 0.4052

# %%
# edited the confusion_matrix.py to have "figsize=( num_classes, num_classes ))"" for better image output

# !python mmdetection/tools/analysis_tools/confusion_matrix.py\
 drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_cfg.py\
  drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/predictions.pkl\
   drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output --show
# Out:
# 2025-07-19 16:53:21.591121: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752944001.612717  102398 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752944001.619297  102398 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 374/374, 2412.1 task/s, elapsed: 0s, ETA:     0sFigure(700x700)

# %%
cm = mmcv.imread('drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/confusion_matrix.png')
cm = mmcv.imconvert(cm, 'bgr', 'rgb')
plt.imshow(cm)
plt.axis('off')
plt.show()

# %%
# Replace this
# per_label_sums = confusion_matrix.sum(axis=1)[:, np.newaxis]
# confusion_matrix = \
#     confusion_matrix.astype(np.float32) / per_label_sums * 100

# With this
# confusion_matrix = confusion_matrix.astype(np.int32)

# And update the annotation text (inside the double for-loop)
# From this
# '{}%'

# To this
# '{}'

# also make  title='Confusion Matrix'

# save image as confusion_matrix2.png

# chnages in onfusion_matrix.py


# !python mmdetection/tools/analysis_tools/confusion_matrix.py\
 drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_cfg.py\
  drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/predictions.pkl\
   drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output --show
# Out:
# 2025-08-15 13:34:21.805019: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755264861.826582   18696 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755264861.833122   18696 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755264861.849664   18696 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755264861.849692   18696 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755264861.849694   18696 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755264861.849697   18696 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# loading annotations into memory...
# Done (t=1.64s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 374/374, 2165.3 task/s, elapsed: 0s, ETA:     0sFigure(700x700)

# %%
cm = mmcv.imread('drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/confusion_matrix2.png')
cm = mmcv.imconvert(cm, 'bgr', 'rgb')
plt.imshow(cm)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Test for time

# %%
# !python mmdetection/tools/analysis_tools/benchmark.py \
    drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_cfg.py \
    --checkpoint drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/epoch_24_weights_only.pth \
    --task inference \
    --log-interval 100 \
    --dataset-type test
# Out:
# 07/19 16:58:22 - mmengine - INFO - before build:
# 07/19 16:58:22 - mmengine - INFO - (GB) mem_used: 3.55 | uss: 0.44 | pss: 0.57 | total_proc: 1
# 2025-07-19 16:58:23.997538: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752944304.018750  103806 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752944304.025287  103806 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loads checkpoint by local backend from path: drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/epoch_24_weights_only.pth
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer1.0.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer1.1.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer1.2.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer2.0.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer2.1.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer2.2.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer2.3.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.0.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.1.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.2.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.3.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.4.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.5.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.6.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.7.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.8.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.9.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.10.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.11.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.12.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.13.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.14.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.15.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.16.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.17.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.18.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.19.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.20.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.21.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer3.22.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer4.0.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer4.1.conv2 is upgraded to version 2.
# 07/19 16:58:28 - mmengine - INFO - DeformConv2dPack backbone.layer4.2.conv2 is upgraded to version 2.
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# 07/19 16:58:29 - mmengine - INFO - after build:
# 07/19 16:58:29 - mmengine - INFO - (GB) mem_used: 4.37 | uss: 1.28 | pss: 1.56 | total_proc: 1
# /content/mmdetection/mmdet/models/roi_heads/mask_heads/fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#   mask_preds = bboxes.new_tensor(mask_preds)
# 07/19 16:58:41 - mmengine - INFO - ==================================
# 07/19 16:58:41 - mmengine - INFO - Done image [100/2000], fps: 11.0 img/s, times per image: 91.2 ms/img, cuda memory: 880 MB
# 07/19 16:58:41 - mmengine - INFO - (GB) mem_used: 4.74 | uss: 1.75 | pss: 2.04 | total_proc: 1
# 07/19 16:58:52 - mmengine - INFO - ==================================
# 07/19 16:58:52 - mmengine - INFO - Done image [200/2000], fps: 11.2 img/s, times per image: 89.4 ms/img, cuda memory: 880 MB
# 07/19 16:58:52 - mmengine - INFO - (GB) mem_used: 4.74 | uss: 1.75 | pss: 2.03 | total_proc: 1
# 07/19 16:59:03 - mmengine - INFO - ==================================
# 07/19 16:59:03 - mmengine - INFO - Done image [300/2000], fps: 11.2 img/s, times per image: 89.6 ms/img, cuda memory: 861 MB
# 07/19 16:59:03 - mmengine - INFO - (GB) mem_used: 4.75 | uss: 1.76 | pss: 2.05 | total_proc: 1
# 07/19 16:59:11 - mmengine - INFO - ============== Done ==================
# 07/19 16:59:11 - mmengine - INFO - Overall fps: 11.2 img/s, times per image: 89.3 ms/img
# 07/19 16:59:11 - mmengine - INFO - cuda memory: 868 MB
# 07/19 16:59:11 - mmengine - INFO - (GB) mem_used: 4.73 | uss: 1.77 | pss: 2.05 | total_proc: 1

# %% [markdown]
# ## images test
# - this is used in the "all_models_images" to test all models togather

# %%
def inference_on_image(img_path, model, threshold=0.5):
    # Load and convert image
    img = mmcv.imread(img_path)
    img = mmcv.imconvert(img, 'bgr', 'rgb')

    visualizer = VISUALIZERS.build(model.cfg.visualizer)
    visualizer.dataset_meta = {
        'classes': ('dent', 'scratch', 'crack', 'glass shatter', 'lamp broken', 'tire flat'),
        'palette': [(220, 20, 60), (119, 11, 32), (0, 0, 142),
                    (0, 0, 230), (106, 0, 228), (0, 60, 100)]
    }

    result = inference_detector(model, img)
    predictions = result.pred_instances

    # Filter predictions by threshold
    indices = predictions.scores >= threshold
    filtered_masks = predictions.masks[indices]
    filtered_bboxes = predictions.bboxes[indices]
    filtered_labels = predictions.labels[indices]
    filtered_scores = predictions.scores[indices]

    filtered_predictions = InstanceData(
        masks=filtered_masks,
        bboxes=filtered_bboxes,
        labels=filtered_labels,
        scores=filtered_scores
    )
    result.pred_instances = filtered_predictions

    # visualizer
    visualizer.add_datasample(
        'result',
        img,
        data_sample=result,
        draw_gt=False,
        show=False
    )
    frame = visualizer.get_image()

    # damage info
    classes = visualizer.dataset_meta['classes']
    label_counts = {}
    for label in filtered_labels:
        class_name = classes[label]
        label_counts[class_name] = label_counts.get(class_name, 0) + 1

    print(f"\nTotal Damages Detected: {len(filtered_labels)}")
    for damage_type, count in label_counts.items():
        print(f"- {damage_type}: {count}")

    # original img and result img side by side
    fig, axs = plt.subplots(1, 2, figsize=(14, 7))
    axs[0].imshow(img)
    axs[0].set_title("Original Image")
    axs[0].axis('off')

    axs[1].imshow(frame)
    axs[1].set_title("Detected Damages")
    axs[1].axis('off')

    plt.tight_layout()
    plt.show()

# %%
config_file = 'drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_cfg.py'

checkpoint_file = 'drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/epoch_24_weights_only.pth'
# Build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device= 0)
# Out:
# Loads checkpoint by local backend from path: drive/MyDrive/damage_detection/cascade-mask-rcnn_x101_output/epoch_24_weights_only.pth
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer1.0.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer1.1.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer1.2.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer2.0.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer2.1.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer2.2.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer2.3.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.0.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.1.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.2.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.3.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.4.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.5.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.6.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.7.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.8.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.9.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.10.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.11.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.12.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.13.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.14.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.15.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.16.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.17.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.18.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.19.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.20.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.21.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer3.22.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer4.0.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer4.1.conv2 is upgraded to version 2.
# 07/19 16:59:58 - mmengine - INFO - DeformConv2dPack backbone.layer4.2.conv2 is upgraded to version 2.
# /content/mmdetection/mmdet/apis/inference.py:90: UserWarning: dataset_meta or class names are not saved in the checkpoint's meta data, use COCO classes by default.
#   warnings.warn(

# %%
warnings.filterwarnings("ignore", category=UserWarning) # Hide warning when plotting the prediction
